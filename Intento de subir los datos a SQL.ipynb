# %%
import requests
import pandas as pd

# %%
url = "https://data.cityofchicago.org/resource/crimes.json"
response = requests.get(url)

# %%
if response.status_code == 200:
    datos = response.json()
    print(datos)
else:
    print("descargar archivo")
# Out:
# [{'id': '13004854', 'case_number': 'JG179018', 'date': '2023-03-08T23:50:00.000', 'block': '069XX S UNION AVE', 'iucr': '0486', 'primary_type': 'BATTERY', 'description': 'DOMESTIC BATTERY SIMPLE', 'location_description': 'APARTMENT', 'arrest': False, 'domestic': True, 'beat': '0732', 'district': '007', 'ward': '6', 'community_area': '68', 'fbi_code': '08B', 'x_coordinate': '1172833', 'y_coordinate': '1858894', 'year': '2023', 'updated_on': '2023-03-15T16:49:38.000', 'latitude': '41.76823645', 'longitude': '-87.642040549', 'location': {'latitude': '41.76823645', 'longitude': '-87.642040549', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_awaf_s7ux': '31', ':@computed_region_6mkv_f3dw': '21559', ':@computed_region_vrxf_vc4k': '66', ':@computed_region_bdys_3d7i': '479', ':@computed_region_43wa_7qmu': '32', ':@computed_region_rpca_8um6': '11', ':@computed_region_d9mm_jgwp': '17', ':@computed_region_d3ds_rm58': '214'}, {'id': '13004824', 'case_number': 'JG179005', 'date': '2023-03-08T23:40:00.000', 'block': '009XX N MICHIGAN AVE', 'iucr': '0486', 'primary_type': 'BATTERY', 'description': 'DOMESTIC BATTERY SIMPLE', 'location_description': 'HOTEL / MOTEL', 'arrest': False, 'domestic': True, 'beat': '1833', 'district': '018', 'ward': '2', 'community_area': '8', 'fbi_code': '08B', 'x_coordinate': '1177322', 'y_coordinate': '1906785', 'year': '2023', 'updated_on': '2023-03-15T16:49:38.000', 'latitude': '41.899552895', 'longitude': '-87.624137033', 'location': {'latitude': '41.899552895', 'longitude': '-87.624137033', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_awaf_s7ux': '22', ':@computed_region_6mkv_f3dw': '21182', ':@computed_region_vrxf_vc4k': '37', ':@computed_region_bdys_3d7i': '104', ':@computed_region_43wa_7qmu': '36', ':@computed_region_rpca_8um6': '6', ':@computed_region_d9mm_jgwp': '14', ':@computed_region_d3ds_rm58': '71'}, {'id': '13004816', 'case_number': 'JG179011', 'date': '2023-03-08T23:33:00.000', 'block': '062XX S MAPLEWOOD AVE', 'iucr': '1320', 'primary_type': 'CRIMINAL DAMAGE', 'description': 'TO VEHICLE', 'location_description': 'STREET', 'arrest': False, 'domestic': True, 'beat': '0825', 'district': '008', 'ward': '16', 'community_area': '66', 'fbi_code': '14', 'x_coordinate': '1160443', 'y_coordinate': '1863219', 'year': '2023', 'updated_on': '2023-03-15T16:49:38.000', 'latitude': '41.780369155', 'longitude': '-87.687336877', 'location': {'latitude': '41.780369155', 'longitude': '-87.687336877', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_awaf_s7ux': '44', ':@computed_region_6mkv_f3dw': '21867', ':@computed_region_vrxf_vc4k': '64', ':@computed_region_bdys_3d7i': '111', ':@computed_region_43wa_7qmu': '2', ':@computed_region_rpca_8um6': '58', ':@computed_region_d9mm_jgwp': '13', ':@computed_region_d3ds_rm58': '274'}, {'id': '13005117', 'case_number': 'JG179391', 'date': '2023-03-08T23:30:00.000', 'block': '003XX W 109TH PL', 'iucr': '051A', 'primary_type': 'ASSAULT', 'description': 'AGGRAVATED - HANDGUN', 'location_description': 'STREET', 'arrest': False, 'domestic': True, 'beat': '0513', 'district': '005', 'ward': '34', 'community_area': '49', 'fbi_code': '04A', 'x_coordinate': '1175943', 'y_coordinate': '1832310', 'year': '2023', 'updated_on': '2023-03-15T16:49:38.000', 'latitude': '41.69521733', 'longitude': '-87.6314356', 'location': {'latitude': '41.69521733', 'longitude': '-87.6314356', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_awaf_s7ux': '45', ':@computed_region_6mkv_f3dw': '21861', ':@computed_region_vrxf_vc4k': '45', ':@computed_region_bdys_3d7i': '524', ':@computed_region_43wa_7qmu': '22', ':@computed_region_rpca_8um6': '19', ':@computed_region_d9mm_jgwp': '10', ':@computed_region_d3ds_rm58': '260'}, {'id': '13006509', 'case_number': 'JG179016', 'date': '2023-03-08T23:30:00.000', 'block': '079XX S PRAIRIE AVE', 'iucr ...

# %%
chicago = pd.read_json('https://data.cityofchicago.org/resource/crimes.json')

# %%
chicago.columns
# Out:
# Index(['id', 'case_number', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'arrest', 'domestic', 'beat',
#        'district', 'ward', 'community_area', 'fbi_code', 'x_coordinate',
#        'y_coordinate', 'year', 'updated_on', 'latitude', 'longitude',
#        'location', ':@computed_region_awaf_s7ux',
#        ':@computed_region_6mkv_f3dw', ':@computed_region_vrxf_vc4k',
#        ':@computed_region_bdys_3d7i', ':@computed_region_43wa_7qmu',
#        ':@computed_region_rpca_8um6', ':@computed_region_d9mm_jgwp',
#        ':@computed_region_d3ds_rm58'],
#       dtype='object')

# %%
chicago.head()
# Out:
#          id case_number                date                  block  iucr  \
# 0  13004854    JG179018 2023-03-08 23:50:00      069XX S UNION AVE  0486
# 1  13004824    JG179005 2023-03-08 23:40:00   009XX N MICHIGAN AVE  0486
# 2  13004816    JG179011 2023-03-08 23:33:00  062XX S MAPLEWOOD AVE  1320
# 3  13005117    JG179391 2023-03-08 23:30:00       003XX W 109TH PL  051A
# 4  13006509    JG179016 2023-03-08 23:30:00    079XX S PRAIRIE AVE  141A
#
#         primary_type              description location_description  arrest  \
# 0            BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 1            BATTERY  DOMESTIC BATTERY SIMPLE        HOTEL / MOTEL   False
# 2    CRIMINAL DAMAGE               TO VEHICLE               STREET   False
# 3            ASSAULT     AGGRAVATED - HANDGUN               STREET   False
# 4  WEAPONS VIOLATION   UNLAWFUL USE - HANDGUN            RESIDENCE   False
#
#    domestic  ...  longitude  \
# 0      True  ... -87.642041
# 1      True  ... -87.624137
# 2      True  ... -87.687337
# 3      True  ... -87.631436
# 4     False  ... -87.618131
#
#                                             location  \
# 0  {'latitude': '41.76823645', 'longitude': '-87....
# 1  {'latitude': '41.899552895', 'longitude': '-87...
# 2  {'latitude': '41.780369155', 'longitude': '-87...
# 3  {'latitude': '41.69521733', 'longitude': '-87....
# 4  {'latitude': '41.750213733', 'longitude': '-87...
#
#    :@computed_region_awaf_s7ux  :@computed_region_6mkv_f3dw  \
# 0                         31.0                      21559.0
# 1                         22.0                      21182.0
# 2                         44.0                      21867.0
# 3                         45.0                      21861.0
# 4                         31.0                      21546.0
#
#   :@computed_region_vrxf_vc4k  :@computed_region_bdys_3d7i  \
# 0                        66.0                        479.0
# 1                        37.0                        104.0
# 2                        64.0                        111.0
# 3                        45.0                        524.0
# 4                        40.0                        406.0
#
#    :@computed_region_43wa_7qmu  :@computed_region_rpca_8um6  \
# 0                         32.0                         11.0
# 1                         36.0                          6.0
# 2                          2.0                         58.0
# 3                         22.0                         19.0
# 4                         32.0                         61.0
#
#   :@computed_region_d9mm_jgwp  :@computed_region_d3ds_rm58
# 0                        17.0                        214.0
# 1                        14.0                         71.0
# 2                        13.0                        274.0
# 3                        10.0                        260.0
# 4                        20.0                        228.0
#
# [5 rows x 30 columns]

# %%
#%pip install mysql-connector-python

# %%
chicago=pd.read_csv(r"Crimes_Chicago.csv" , encoding='iso-8859-1')
# Out:
# C:\Users\jelsa\AppData\Local\Temp\ipykernel_19204\4255278803.py:1: DtypeWarning: Columns (0,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   chicago=pd.read_csv(r"Crimes_Chicago.csv" , encoding='iso-8859-1')

# %%
import pandas as pd
import mysql.connector

# %%
crimesus = mysql.connector.connect(
  host="127.0.0.1",
  user="jel",
  password="Galdames1",
  database="crimesus")

# %%
mycursor = crimesus.cursor()

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651661 entries, 0 to 651660
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    651661 non-null  object
#  1   Case Number           651657 non-null  object
#  2   Date                  651657 non-null  object
#  3   Block                 651656 non-null  object
#  4   IUCR                  651656 non-null  object
#  5   Primary Type          651656 non-null  object
#  6   Description           651656 non-null  object
#  7   Location Description  649562 non-null  object
#  8   Arrest                651656 non-null  object
#  9   Domestic              651656 non-null  object
#  10  Beat                  651656 non-null  float64
#  11  District              651656 non-null  float64
#  12  Ward                  651537 non-null  float64
#  13  Community Area        651543 non-null  float64
#  14  FBI Code              651656 non-null  object
#  15  X Coordinate          647399 non-null  float64
#  16  Y Coordinate          647399 non-null  float64
#  17  Year                  651656 non-null  float64
#  18  Updated On            651656 non-null  object
#  19  Latitude              647399 non-null  float64
#  20  Longitude             647399 non-null  float64
#  21  Location              647399 non-null  object
# dtypes: float64(9), object(13)
# memory usage: 109.4+ MB

# %%
import json
import pymysql
import pandas as pd

# %%
connection = pymysql.connect(host='127.0.0.1',
                             user='jel',
                             password='Galdames1',
                             db='crimesus')

# %%
chicago = pd.read_json('https://data.cityofchicago.org/resource/crimes.json')

# %%
chicago.to_sql('crimesus', con=connection, if_exists='replace', index=False)

# %%
connection.close()
