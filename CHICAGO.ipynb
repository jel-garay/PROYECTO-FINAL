# %%
import requests
import pandas as pd

# %%
url = "https://data.cityofchicago.org/resource/crimes.json"
response = requests.get(url)

# %%
if response.status_code == 200:
    datos = response.json()
    print(datos)
else:
    print("descargar archivo")
# Out:
# [{'id': '13000913', 'case_number': 'JG174323', 'date': '2023-03-04T23:57:00.000', 'block': '059XX S FRANCISCO AVE', 'iucr': '0560', 'primary_type': 'ASSAULT', 'description': 'SIMPLE', 'location_description': 'RESIDENCE', 'arrest': True, 'domestic': True, 'beat': '0824', 'district': '008', 'ward': '16', 'community_area': '66', 'fbi_code': '08A', 'x_coordinate': '1158062', 'y_coordinate': '1865140', 'year': '2023', 'updated_on': '2023-03-11T15:48:26.000', 'latitude': '41.785689405', 'longitude': '-87.696013884', 'location': {'latitude': '41.785689405', 'longitude': '-87.696013884', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}}, {'id': '13000908', 'case_number': 'JG174325', 'date': '2023-03-04T23:56:00.000', 'block': '020XX S MICHIGAN AVE', 'iucr': '143A', 'primary_type': 'WEAPONS VIOLATION', 'description': 'UNLAWFUL POSSESSION - HANDGUN', 'location_description': 'STREET', 'arrest': True, 'domestic': False, 'beat': '0132', 'district': '001', 'ward': '3', 'comm
# ...

# %%
chicago = pd.read_json('https://data.cityofchicago.org/resource/crimes.json')

# %%
chicago.head() # vemos una vision general del dataframe
# Out:
#          id case_number                date                  block  iucr  \
# 0  13000913    JG174323 2023-03-04 23:57:00  059XX S FRANCISCO AVE  0560
# 1  13000908    JG174325 2023-03-04 23:56:00   020XX S MICHIGAN AVE  143A
# 2  13001044    JG174494 2023-03-04 23:56:00      019XX W OGDEN AVE  0454
# 3  13000902    JG174321 2023-03-04 23:56:00      059XX S MORGAN ST  143A
# 4  13001594    JG174839 2023-03-04 23:50:00     026XX N HALSTED ST  0870
#
#         primary_type                                        description  \
# 0            ASSAULT                                             SIMPLE
# 1  WEAPONS VIOLATION                      UNLAWFUL POSSESSION - HANDGUN
# 2            BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
# 3  WEAPONS VIOLATION                      UNLAWFUL POSSESSION - HANDGUN
# 4              THEFT                                     POCKET-PICKING
#
#           location_description  arrest  domestic  ...  longitude  \
# ...

# %%
chicago.columns # observamos que columnas tiene
# Out:
# Index(['id', 'case_number', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'arrest', 'domestic', 'beat',
#        'district', 'ward', 'community_area', 'fbi_code', 'x_coordinate',
#        'y_coordinate', 'year', 'updated_on', 'latitude', 'longitude',
#        'location', ':@computed_region_awaf_s7ux',
#        ':@computed_region_6mkv_f3dw', ':@computed_region_vrxf_vc4k',
#        ':@computed_region_bdys_3d7i', ':@computed_region_43wa_7qmu',
#        ':@computed_region_rpca_8um6', ':@computed_region_d9mm_jgwp',
#        ':@computed_region_d3ds_rm58'],
#       dtype='object')

# %%
# CHEQUEAMOS QUE HAY EN CADA CONCEPTO PARA PODER ENTENDERLO

# %%
theft_data = chicago.loc[chicago['primary_type'] == 'THEFT']  
theft_data
# Out:
#            id case_number                date                  block  iucr  \
# 4    13001594    JG174839 2023-03-04 23:50:00     026XX N HALSTED ST  0870
# 13   13001591    JG175101 2023-03-04 23:15:00     007XX N WILLARD CT  0890
# 20   13002399    JG176242 2023-03-04 23:00:00      006XX W CERMAK RD  0820
# 22   13001047    JG174264 2023-03-04 23:00:00     049XX W GLADYS AVE  0810
# 25   13006104    JG179479 2023-03-04 23:00:00        017XX E 73RD PL  0810
# ..        ...         ...                 ...                    ...   ...
# 987  12999628    JG172971 2023-03-03 10:00:00  064XX S FAIRFIELD AVE  0890
# 988  12999240    JG172398 2023-03-03 10:00:00    041XX S INDIANA AVE  0870
# 990  12999817    JG172800 2023-03-03 10:00:00    016XX W CARROLL AVE  0810
# 994  12999372    JG172381 2023-03-03 10:00:00     013XX N PAULINA ST  0850
# 999  12999222    JG172362 2023-03-03 09:55:00   024XX N LAKEVIEW AVE  0810
#
# ...

# %%
theft_descriptions = theft_data['description'].unique()
theft_descriptions
# Out:
# array(['POCKET-PICKING', 'FROM BUILDING', '$500 AND UNDER', 'OVER $500',
#        'PURSE-SNATCHING', 'RETAIL THEFT', 'DELIVERY CONTAINER THEFT',
#        'ATTEMPT THEFT'], dtype=object)

# %%
battery_data = chicago.loc[chicago['primary_type'] == 'BATTERY']
battery_data
# Out:
#            id case_number                date                 block  iucr  \
# 2    13001044    JG174494 2023-03-04 23:56:00     019XX W OGDEN AVE  0454
# 9    13000897    JG174317 2023-03-04 23:35:00  045XX W MARQUETTE RD  0497
# 10   13000872    JG174293 2023-03-04 23:31:00      006XX W 117TH PL  0486
# 11   13000910    JG174326 2023-03-04 23:30:00    015XX S HAMLIN AVE  0454
# 28   13001345    JG174781 2023-03-04 23:00:00  109XX S EBERHART AVE  0460
# ..        ...         ...                 ...                   ...   ...
# 951  13002152    JG175619 2023-03-03 11:00:00   016XX S DEARBORN ST  0460
# 956  12999444    JG172408 2023-03-03 10:55:00   131XX S LANGLEY AVE  0486
# 958  12999494    JG172454 2023-03-03 10:50:00    036XX S WABASH AVE  0484
# 972  12999369    JG172393 2023-03-03 10:30:00   014XX N ROCKWELL ST  0486
# 992  12999434    JG172441 2023-03-03 10:00:00   029XX W BELMONT AVE  0486
#
#     primary_type                                        description  \
# ...

# %%
battery_descriptions = battery_data['description'].unique()
battery_descriptions
# Out:
# array(['AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MINOR INJURY',
#        'AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON',
#        'DOMESTIC BATTERY SIMPLE', 'SIMPLE',
#        'AGGRAVATED OF A SENIOR CITIZEN',
#        'AGGRAVATED - KNIFE / CUTTING INSTRUMENT', 'AGGRAVATED - HANDGUN',
#        'AGGRAVATED - OTHER DANGEROUS WEAPON',
#        'AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON',
#        'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY',
#        'AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY',
#        'AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT',
#        'AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY'], dtype=object)

# %%
deceptive_data = chicago.loc[chicago['primary_type'] == 'DECEPTIVE PRACTICE']
deceptive_data.head()
# Out:
#            id case_number                date                block  iucr  \
# 62   13001689    JG174236 2023-03-04 21:15:00  021XX W DIVISION ST  1210
# 67   13001543    JG175139 2023-03-04 21:03:00    019XX W OGDEN AVE  1220
# 89   13004665    JG178070 2023-03-04 20:16:00   010XX W ADDISON ST  1210
# 92   13001205    JG174736 2023-03-04 20:07:00      032XX W 63RD ST  1153
# 103  13000705    JG174165 2023-03-04 20:00:00     005XX N STATE ST  1210
#
#            primary_type                          description  \
# 62   DECEPTIVE PRACTICE            THEFT OF LABOR / SERVICES
# 67   DECEPTIVE PRACTICE     THEFT OF LOST / MISLAID PROPERTY
# 89   DECEPTIVE PRACTICE            THEFT OF LABOR / SERVICES
# 92   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 103  DECEPTIVE PRACTICE            THEFT OF LABOR / SERVICES
#
#                        location_description  arrest  domestic  ...  longitude  \
# ...

# %%
deceptive_descriptions = deceptive_data['description'].unique()
deceptive_descriptions
# Out:
# array(['THEFT OF LABOR / SERVICES', 'THEFT OF LOST / MISLAID PROPERTY',
#        'FINANCIAL IDENTITY THEFT OVER $ 300', 'CREDIT CARD FRAUD',
#        'FINANCIAL IDENTITY THEFT $300 AND UNDER', 'ILLEGAL USE CASH CARD',
#        'ATTEMPT - FINANCIAL IDENTITY THEFT', 'FORGERY',
#        'FRAUD OR CONFIDENCE GAME', 'COMPUTER FRAUD'], dtype=object)

# %%
motor_data = chicago.loc[chicago['primary_type'] == 'MOTOR VEHICLE THEFT']
motor_data
# Out:
#            id case_number                date                   block  iucr  \
# 14   13002112    JG175852 2023-03-04 23:15:00     123XX S EMERALD AVE  0930
# 19   13001708    JG175263 2023-03-04 23:00:00      047XX W GLADYS AVE  0910
# 23   13001405    JG174704 2023-03-04 23:00:00     061XX S KENNETH AVE  0910
# 24   13001560    JG174910 2023-03-04 23:00:00     047XX N KENNETH AVE  0915
# 26   13001427    JG174796 2023-03-04 23:00:00       008XX S BISHOP ST  0910
# ..        ...         ...                 ...                     ...   ...
# 943  12999546    JG172569 2023-03-03 11:30:00      082XX S VERNON AVE  0910
# 949  13004483    JG178467 2023-03-03 11:00:00        100XX W OHARE ST  0910
# 950  12999664    JG172594 2023-03-03 11:00:00   033XX W HUTCHINSON ST  0920
# 974  12999418    JG172546 2023-03-03 10:28:00         002XX W 24TH ST  0930
# 981  12999284    JG172406 2023-03-03 10:09:00  080XX S MARSHFIELD AVE  0910
#
# ...

# %%
motor_descriptions = motor_data['description'].unique()
motor_descriptions
# Out:
# array(['THEFT / RECOVERY - AUTOMOBILE', 'AUTOMOBILE',
#        'TRUCK, BUS, MOTOR HOME', 'ATTEMPT - AUTOMOBILE'], dtype=object)

# %%
criminal_data = chicago.loc[chicago['primary_type'] == 'CRIMINAL DAMAGE']
criminal_data
# Out:
#            id case_number                date                  block  iucr  \
# 6    13000879    JG174307 2023-03-04 23:42:00  048XX N MILWAUKEE AVE  1305
# 17   13001029    JG174309 2023-03-04 23:01:00   074XX S EAST END AVE  1320
# 30   13000857    JG174263 2023-03-04 22:56:00    010XX W NEWPORT AVE  1310
# 55   13000923    JG174285 2023-03-04 21:36:00    060XX S WOLCOTT AVE  1320
# 60   13000831    JG174232 2023-03-04 21:20:00        0000X E 49TH ST  1310
# ..        ...         ...                 ...                    ...   ...
# 911  12999430    JG172548 2023-03-03 12:25:00    003XX S DEARBORN ST  1310
# 955  13000519    JG173797 2023-03-03 11:00:00        023XX E 70TH ST  1320
# 967  12999293    JG172448 2023-03-03 10:40:00  001XX W WASHINGTON ST  1310
# 984  12999683    JG172873 2023-03-03 10:01:00  074XX S CHAMPLAIN AVE  1310
# 993  12999442    JG172367 2023-03-03 10:00:00    112XX S INDIANA AVE  1310
#
# ...

# %%
criminal_descriptions = criminal_data['description'].unique()
criminal_descriptions
# Out:
# array(['CRIMINAL DEFACEMENT', 'TO VEHICLE', 'TO PROPERTY',
#        'TO CITY OF CHICAGO PROPERTY'], dtype=object)

# %%
assault_data = chicago.loc[chicago['primary_type'] == 'ASSAULT']
assault_data
# Out:
#            id case_number                date  \
# 0    13000913    JG174323 2023-03-04 23:57:00
# 15   13001756    JG174280 2023-03-04 23:08:00
# 39   13001195    JG174255 2023-03-04 22:24:00
# 53   13000850    JG174235 2023-03-04 21:45:00
# 64   13000855    JG174220 2023-03-04 21:11:00
# ..        ...         ...                 ...
# 969  12999339    JG172433 2023-03-03 10:31:00
# 970  13000132    JG173399 2023-03-03 10:30:00
# 971  12999759    JG172559 2023-03-03 10:30:00
# 979  12999262    JG172373 2023-03-03 10:15:00
# 996  12999397    JG172386 2023-03-03 10:00:00
#
#                                    block  iucr primary_type  \
# 0                  059XX S FRANCISCO AVE  0560      ASSAULT
# 15   023XX S DR MARTIN LUTHER KING JR DR  0520      ASSAULT
# 39                    035XX S HALSTED ST  0560      ASSAULT
# 53                  073XX S PHILLIPS AVE  051A      ASSAULT
# 64                   046XX W MAYPOLE AVE  051A      ASSAULT
# ...

# %%
assault_descriptions = assault_data['description'].unique()
assault_descriptions
# Out:
# array(['SIMPLE', 'AGGRAVATED - KNIFE / CUTTING INSTRUMENT',
#        'AGGRAVATED - HANDGUN', 'AGGRAVATED - OTHER FIREARM',
#        'AGGRAVATED - OTHER DANGEROUS WEAPON',
#        'PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY'],
#       dtype=object)

# %%
# VOY A INDAGAR CORRELACIONES ENTRE LAS COLUMNAS A VER SI TIENEN RELACION ENTRE SÍ

# %%
table = pd.crosstab(chicago['block'], chicago['description'])

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(table)

if p < 0.05:
    print("Existe una correlación estadísticamente significativa entre 'block' y 'description'.")
else:
    print("No existe una correlación estadísticamente significativa entre 'block' y 'description'.")
# Out:
# Existe una correlación estadísticamente significativa entre 'block' y 'description'.

# %%
table = pd.crosstab(chicago['arrest'], chicago['description'])

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(table)

if p < 0.05:
    print("Existe una correlación estadísticamente significativa entre 'arrest' y 'description'.")
else:
    print("No existe una correlación estadísticamente significativa entre 'arrest' y 'description'.")
# Out:
# Existe una correlación estadísticamente significativa entre 'arrest' y 'description'.

# %%
table = pd.crosstab(chicago['date'], chicago['description'])

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(table)

if p < 0.05:
    print("Existe una correlación estadísticamente significativa entre 'date' y 'description'.")
else:
    print("No existe una correlación estadísticamente significativa entre 'date' y 'description'.")
# Out:
# Existe una correlación estadísticamente significativa entre 'date' y 'description'.

# %%
table = pd.crosstab(chicago['date'], chicago['arrest'])

# %%
from scipy.stats import chi2_contingency

chi2, p, dof, expected = chi2_contingency(table)

if p < 0.05:
    print("Existe una correlación estadísticamente significativa entre 'date' y 'arrest'.")
else:
    print("No existe una correlación estadísticamente significativa entre 'date' y 'arrest'.")
# Out:
# Existe una correlación estadísticamente significativa entre 'date' y 'arrest'.

# %%
chicago['hour'] = chicago['date'].dt.hour

# %%
crimes_by_hour = chicago.groupby(['hour', 'description']).size().reset_index(name='count')

# %%
idx = crimes_by_hour.groupby(['hour'])['count'].transform(max) == crimes_by_hour['count']
crimes_by_hour_max = crimes_by_hour[idx]

# %%
print(crimes_by_hour_max) #delitos mas comunes por hora
# Out:
#      hour              description  count
# 0       0           $500 AND UNDER      4
# 25      1  DOMESTIC BATTERY SIMPLE      5
# 39      2               AUTOMOBILE      4
# 52      3  DOMESTIC BATTERY SIMPLE      5
# 61      4               AUTOMOBILE      2
# 65      4               TO VEHICLE      2
# 70      5              TO PROPERTY      6
# 73      6           $500 AND UNDER      2
# 81      7           FORCIBLE ENTRY      2
# 84      7                   SIMPLE      2
# 93      8  DOMESTIC BATTERY SIMPLE      3
# 113     9                OVER $500      3
# 119     9               TO VEHICLE      3
# 141    10                   SIMPLE      8
# 168    11                   SIMPLE      9
# 198    12                   SIMPLE     11
# 222    13                   SIMPLE      6
# 255    14                   SIMPLE      6
# 276    15                   SIMPLE     20
# 301    16                   SIMPLE     10
# 312    17               AUTOMOBILE      6
# ...

# %%
chicago['hour'] = chicago['date'].dt.hour

# %%
crimes_by_hour = chicago.groupby(['hour', 'primary_type']).size().reset_index(name='count')

# %%
idx = crimes_by_hour.groupby(['hour'])['count'].transform(max) == crimes_by_hour['count']
crimes_by_hour_max = crimes_by_hour[idx]

# %%
print(crimes_by_hour_max) #delitos mas comunes por hora
# Out:
#      hour         primary_type  count
# 10      0                THEFT      7
# 12      1              BATTERY      7
# 21      2              BATTERY      7
# 27      3              BATTERY      9
# 38      4      CRIMINAL DAMAGE      3
# 42      5      CRIMINAL DAMAGE      8
# 49      6                THEFT      3
# 50      7              ASSAULT      2
# 52      7             BURGLARY      2
# 56      7        OTHER OFFENSE      2
# 60      8              BATTERY      5
# 66      8                THEFT      5
# 78      9                THEFT      8
# 91     10                THEFT     15
# 94     11              BATTERY     12
# 103    11                THEFT     12
# 106    12              BATTERY     11
# 131    13                THEFT     16
# 144    14                THEFT     14
# 147    15              BATTERY     23
# 167    16                THEFT     17
# 181    17                THEFT     10
# 195    18                THEFT     16
# 197    19              ASSAULT     10
# ...

# %%
crimes_by_hour = chicago.groupby(['hour', 'location_description']).size().reset_index(name='count')

# %%
crimes_by_district = chicago.groupby(['district', 'description']).size()

# %%
most_common_crime_idx = crimes_by_district.groupby('district').idxmax()

# %%
most_common_crimes = crimes_by_district.loc[most_common_crime_idx.values]

# %%
print(most_common_crimes) # delitos mas comunes por distrito
# Out:
# district  description
# 1         SIMPLE                     10
# 2         DOMESTIC BATTERY SIMPLE     7
# 3         TO PROPERTY                 6
# 4         $500 AND UNDER              5
# 5         SIMPLE                      9
# 6         DOMESTIC BATTERY SIMPLE    10
# 7         AUTOMOBILE                  6
# 8         SIMPLE                      7
# 9         SIMPLE                      6
# 10        SIMPLE                      5
# 11        SIMPLE                      7
# 12        OVER $500                  12
# 14        $500 AND UNDER              9
# 15        AUTOMOBILE                  5
# 16        SIMPLE                      5
# 17        AUTOMOBILE                  5
# 18        RETAIL THEFT                6
# 19        SIMPLE                      8
# 20        SIMPLE                      3
# 22        DOMESTIC BATTERY SIMPLE     3
# 24        TO VEHICLE                  5
# 25        DOMESTIC BATTERY SIMPLE     5
# dtype: int64

# %%
pivot_table = pd.pivot_table(chicago, values='id', index=['district', 'description'], columns=[chicago['date'].dt.hour], aggfunc='count')

# %%
most_common_crime = pivot_table.idxmax(axis=1)

# %%
print(most_common_crime)
# Out:
# district  description
# 1         $500 AND UNDER                                           0
#           AGGRAVATED - KNIFE / CUTTING INSTRUMENT                 23
#           AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON     3
#           AGGRAVATED OF A SENIOR CITIZEN                          22
#           ARMED - HANDGUN                                         23
#                                                                   ..
# 25        TO VEHICLE                                              18
#           UNLAWFUL ENTRY                                           5
#           UNLAWFUL POSSESSION - HANDGUN                           12
#           VEHICLE TITLE / REGISTRATION OFFENSE                    18
#           VIOLATE ORDER OF PROTECTION                             23
# Length: 484, dtype: int64

# %%
most_common_crime.iloc[:50] # delitos más comunes por distrito y horas
# Out:
# district  description
# 1         $500 AND UNDER                                                 0
#           AGGRAVATED - KNIFE / CUTTING INSTRUMENT                       23
#           AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON           3
#           AGGRAVATED OF A SENIOR CITIZEN                                22
#           ARMED - HANDGUN                                               23
#           AUTOMOBILE                                                    19
#           CREDIT CARD FRAUD                                             12
#           CRIMINAL DEFACEMENT                                           19
#           CRIMINAL SEXUAL ABUSE                                         11
#           DOMESTIC BATTERY SIMPLE                                       19
#           FINANCIAL IDENTITY THEFT OVER $ 300                           14
#           FORCIBLE ENTRY                                                11
# ...

# %%
arrests_by_hour = chicago.groupby(chicago['date'].dt.hour)['arrest'].sum()

# %%
print(arrests_by_hour)  #horas donde hay mas arrestos
# Out:
# date
# 0      4
# 1      5
# 2      1
# 3      3
# 4      0
# 5      0
# 6      0
# 7      2
# 8      2
# 9      1
# 10     7
# 11     6
# 12     6
# 13    16
# 14     9
# 15     6
# 16     7
# 17     6
# 18     9
# 19     5
# 20    10
# 21     7
# 22    11
# 23    14
# Name: arrest, dtype: int64

# %%
arrests_by_description = chicago.groupby('description')['arrest'].sum()

# %%
most_arrests = arrests_by_description.idxmax()

# %%
print(most_arrests) # delito con mas arrestos 'tenencia ilicita de armas' no sorpende chicago no hace falta registrar armas
# Out:
# UNLAWFUL POSSESSION - HANDGUN

# %%
arrests_by_block = chicago.groupby('block')['arrest'].sum()

# %%
most_arrests_block = arrests_by_block.idxmax()

# %%
print(most_arrests_block) # la calle que tiene mas arrestos
# Out:
# 001XX N STATE ST

# %%
filtro_calle = chicago['block'].str.contains('001XX N STATE ST')
chicago_calle = chicago[filtro_calle]

# %%
frecuencia = chicago_calle['description'].value_counts()

# %%
print('El delito más frecuente en 001XX N STATE ST es:', frecuencia.index[0]) # es una calle comercial por lo que los arrestos mas frecuentes tesna asociados a los robos/hurtos de tiendas
# Out:
# El delito más frecuente en 001XX N STATE ST es: RETAIL THEFT

# %%
armed_handgun_crimes = chicago[chicago['description'].str.contains("ARMED - HANDGUN")]

# %%
crimes_by_district_and_description = armed_handgun_crimes.groupby(['district', 'description'])['description'].count()

# %%
most_frequent_crime = crimes_by_district_and_description.idxmax()

# %%
print(most_frequent_crime) # distrito 1
# Out:
# (1, 'ARMED - HANDGUN')

# %%
import folium

# %%
chicago = chicago[chicago['block'].notnull()]

# %%
mapa = folium.Map(location=[41.8781, -87.6298], zoom_start=50)

# %%
chicago= chicago.dropna(subset=['latitude', 'longitude'])

# %%
for index, row in chicago.iterrows():
    ubicacion = [row['latitude'], row['longitude']]
    descripcion = row['description']
    date = row['date']
    arresto = 'ARREST' if row['arrest'] else 'NO ARREST'
    marcador = folium.Marker(location=ubicacion, popup=f'{descripcion}<br>{date}<br>{arresto}')
    marcador.add_to(mapa)
    
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
